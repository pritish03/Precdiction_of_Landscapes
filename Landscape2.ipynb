# %%
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
from keras import backend as K
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
GENERATE_RES = 90 # Generation resolution factor 
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/drive/My Drive/Landscapes'
EPOCHS = 10000
BATCH_SIZE = 100
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 2880px square images.

# %%
# Image set has 11,682 images.  Can take over an hour 
# for initial preprocessing.
# Because of this time needed, save a Numpy preprocessed file.
# Note, that file is large enough to cause problems for 
# sume verisons of Pickle,
# so Numpy binary files are used.
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH,'imagesHigh')
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/drive/My Drive/Landscapes/training_data_96_96.npy
# Loading training images...
# 100%|██████████| 200/200 [01:28<00:00,  2.26it/s]
# Saving training image binary...
# Image preprocess time: 0:01:30.28

# %%
# Batch and shuffle the data
train_dataset = tf.data.Dataset.from_tensor_slices(training_data) \
    .shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] \
            = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.49993116]], shape=(1, 1), dtype=float32)

# %%
# This method returns a helper function to compute cross entropy loss
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(2e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4,0.5)

# %%
# Notice the use of `tf.function`
# This annotation causes the function to be "compiled".
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'\
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=0.5965277552604675,disc loss=1.305034875869751, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=0.6300334930419922,disc loss=1.082694411277771, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=0.6920236349105835,disc loss=1.0106608867645264, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=0.6928844451904297,disc loss=1.0098077058792114, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=0.6927337050437927,disc loss=1.007818341255188, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=0.6925696134567261,disc loss=1.007511019706726, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=0.692656934261322,disc loss=1.0072343349456787, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=0.6925685405731201,disc loss=1.0073142051696777, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=0.6924331784248352,disc loss=1.007422924041748, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=0.6925128698348999,disc loss=1.0074257850646973, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=0.6926554441452026,disc loss=1.0072576999664307, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=0.6925274133682251,disc loss=1.0073297023773193, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=0.6926317811012268,disc loss=1.007319450378418, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=0.6926674842834473,disc loss=1.0071525573730469, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=0.692733883857727,disc loss=1.0070719718933105, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=0.6926938891410828,disc loss=1.0071492195129395, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=0.6926724910736084,disc loss=1.007216215133667, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=0.6927692294120789,disc loss=1.0070483684539795, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=0.6926916837692261,disc loss=1.0070960521697998, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=0.6927008032798767,disc loss=1.007143259048462, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=0.6927698850631714,disc loss=1.0069961547851562, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=0.6927497386932373,disc loss=1.007128357887268, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=0.6927416324615479,disc loss=1.0070675611495972, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=0.6928173303604126,disc loss=1.0069782733917236, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=0.6927987337112427,disc loss=1.0069893598556519, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=0.692855954170227,disc loss=1.0069109201431274, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=0.6928000450134277,disc loss=1.0069992542266846, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=0.6928663849830627,disc loss=1.0068658590316772, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=0.6928757429122925,disc loss=1.0068821907043457, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=0.6927450299263,disc loss=1.0070093870162964, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=0.6927884817123413,disc loss=1.0069546699523926, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=0.6928960084915161,disc loss=1.006881833076477, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=0.692875325679779,disc loss=1.0068683624267578, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=0.692902684211731,disc loss=1.0068285465240479, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=0.6928930282592773,disc loss=1.0068376064300537, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=0.6929095983505249,disc loss=1.0068340301513672, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=0.6929147243499756,disc loss=1.0068063735961914, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=0.6929131746292114,disc loss=1.006812334060669, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=0.6929457187652588,disc loss=1.0067522525787354, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=0.6929309368133545,disc loss=1.006777048110962, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=0.6928478479385376,disc loss=1.0068705081939697, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=0.6929823756217957,disc loss=1.006736159324646, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=0.6929788589477539,disc loss=1.006683349609375, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=0.6930055022239685,disc loss=1.0066721439361572, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=0.6930015087127686,disc loss=1.006664514541626, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=0.6929746866226196,disc loss=1.0066806077957153, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=0.6929542422294617,disc loss=1.006714105606079, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=0.6930277347564697,disc loss=1.0066590309143066, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=0.6930376887321472,disc loss=1.0066241025924683, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=0.6930255889892578,disc loss=1.0066137313842773, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=0.6930131912231445,disc loss=1.0066548585891724, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=0.6930254697799683,disc loss=1.0065932273864746, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=0.6930406093597412,disc loss=1.0066072940826416, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=0.6930181980133057,disc loss=1.0066187381744385, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=0.6930373907089233,disc loss=1.006598711013794, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=0.6930717825889587,disc loss=1.0065643787384033, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=0.693061351776123,disc loss=1.0065667629241943, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=0.6930355429649353,disc loss=1.006592035293579, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=0.6930619478225708,disc loss=1.006554365158081, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=0.6930562257766724,disc loss=1.0065767765045166, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=0.6930510997772217,disc loss=1.0065581798553467, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=0.6930707693099976,disc loss=1.0065354108810425, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=0.693061113357544,disc loss=1.0065467357635498, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=0.6930658221244812,disc loss=1.0065518617630005, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=0.6930786371231079,disc loss=1.0065381526947021, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=0.6930487155914307,disc loss=1.0065574645996094, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=0.6930804252624512,disc loss=1.0065290927886963, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=0.6930704116821289,disc loss=1.006540060043335, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=0.6930783987045288,disc loss=1.006525993347168, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=0.69305020570755,disc loss=1.0065670013427734, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=0.6930962204933167,disc loss=1.0065157413482666, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=0.6930943727493286,disc loss=1.00650954246521, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=0.693081259727478,disc loss=1.0065217018127441, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=0.6930987238883972,disc loss=1.0065070390701294, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=0.6930895447731018,disc loss=1.0065102577209473, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=0.6931018829345703,disc loss=1.0064963102340698, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=0.6931014060974121,disc loss=1.006498098373413, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=0.6931089162826538,disc loss=1.006479024887085, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=0.6931015253067017,disc loss=1.0064932107925415, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=0.6930774450302124,disc loss=1.006516695022583, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=0.6930813789367676,disc loss=1.0065079927444458, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=0.6930986642837524,disc loss=1.0064924955368042, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=0.6931043863296509,disc loss=1.0064867734909058, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=0.6931006908416748,disc loss=1.0064890384674072, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=0.6930856108665466,disc loss=1.0065107345581055, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=0.6931041479110718,disc loss=1.006485104560852, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=0.6931056976318359,disc loss=1.006483554840088, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=0.693105936050415,disc loss=1.0065025091171265, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=0.6931002140045166,disc loss=1.0064889192581177, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=0.693108320236206,disc loss=1.0064764022827148, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=0.6931047439575195,disc loss=1.0064771175384521, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=0.69309401512146,disc loss=1.0064880847930908, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=0.6931017637252808,disc loss=1.0064787864685059, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=0.6930984258651733,disc loss=1.0064797401428223, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=0.6931095123291016,disc loss=1.0064773559570312, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=0.6931228637695312,disc loss=1.006461501121521, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=0.6931077837944031,disc loss=1.0064775943756104, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=0.6931169033050537,disc loss=1.0064668655395508, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=0.6931095123291016,disc loss=1.0064799785614014, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=0.6931173801422119,disc loss=1.0064623355865479, {hms_string(epoch_elapsed)}
# Epoch 101, gen loss=0.6931148171424866,disc loss=1.006462574005127, {hms_string(epoch_elapsed)}
# Epoch 102, gen loss=0.6931154727935791,disc loss=1.0064666271209717, {hms_string(epoch_elapsed)}
# Epoch 103, gen loss=0.6931079626083374,disc loss=1.006471872329712, {hms_string(epoch_elapsed)}
# Epoch 104, gen loss=0.6931037306785583,disc loss=1.0064771175384521, {hms_string(epoch_elapsed)}
# Epoch 105, gen loss=0.6931169033050537,disc loss=1.0064653158187866, {hms_string(epoch_elapsed)}
# Epoch 106, gen loss=0.693120002746582,disc loss=1.0064585208892822, {hms_string(epoch_elapsed)}
# Epoch 107, gen loss=0.6931136846542358,disc loss=1.0064632892608643, {hms_string(epoch_elapsed)}
# Epoch 108, gen loss=0.6931196451187134,disc loss=1.0064573287963867, {hms_string(epoch_elapsed)}
# Epoch 109, gen loss=0.6931065320968628,disc loss=1.0064722299575806, {hms_string(epoch_elapsed)}
# Epoch 110, gen loss=0.6931158304214478,disc loss=1.006460428237915, {hms_string(epoch_elapsed)}
# Epoch 111, gen loss=0.6931216716766357,disc loss=1.0064582824707031, {hms_string(epoch_elapsed)}
# Epoch 112, gen loss=0.6931248903274536,disc loss=1.0064531564712524, {hms_string(epoch_elapsed)}
# Epoch 113, gen loss=0.6931217908859253,disc loss=1.0064551830291748, {hms_string(epoch_elapsed)}
# Epoch 114, gen loss=0.6931246519088745,disc loss=1.006448745727539, {hms_string(epoch_elapsed)}
# Epoch 115, gen loss=0.6931149959564209,disc loss=1.0064575672149658, {hms_string(epoch_elapsed)}
# Epoch 116, gen loss=0.6931157112121582,disc loss=1.0064620971679688, {hms_string(epoch_elapsed)}
# Epoch 117, gen loss=0.6931247711181641,disc loss=1.0064505338668823, {hms_string(epoch_elapsed)}
# Epoch 118, gen loss=0.6931113004684448,disc loss=1.0064607858657837, {hms_string(epoch_elapsed)}
# Epoch 119, gen loss=0.6931241750717163,disc loss=1.0064469575881958, {hms_string(epoch_elapsed)}
# Epoch 120, gen loss=0.693115770816803,disc loss=1.006460428237915, {hms_string(epoch_elapsed)}
# Epoch 121, gen loss=0.6931204795837402,disc loss=1.0064527988433838, {hms_string(epoch_elapsed)}
# Epoch 122, gen loss=0.6931166052818298,disc loss=1.0064609050750732, {hms_string(epoch_elapsed)}
# Epoch 123, gen loss=0.6931276321411133,disc loss=1.006443977355957, {hms_string(epoch_elapsed)}
# Epoch 124, gen loss=0.6931196451187134,disc loss=1.0064547061920166, {hms_string(epoch_elapsed)}
# Epoch 125, gen loss=0.693126916885376,disc loss=1.0064467191696167, {hms_string(epoch_elapsed)}
# Epoch 126, gen loss=0.6931177377700806,disc loss=1.0064560174942017, {hms_string(epoch_elapsed)}
# Epoch 127, gen loss=0.693125307559967,disc loss=1.006450891494751, {hms_string(epoch_elapsed)}
# Epoch 128, gen loss=0.6931275129318237,disc loss=1.0064516067504883, {hms_string(epoch_elapsed)}
# Epoch 129, gen loss=0.6931155323982239,disc loss=1.006455659866333, {hms_string(epoch_elapsed)}
# Epoch 130, gen loss=0.6931271553039551,disc loss=1.006443977355957, {hms_string(epoch_elapsed)}
# Epoch 131, gen loss=0.6931201219558716,disc loss=1.0064529180526733, {hms_string(epoch_elapsed)}
# Epoch 132, gen loss=0.6931251287460327,disc loss=1.0064506530761719, {hms_string(epoch_elapsed)}
# Epoch 133, gen loss=0.6931251287460327,disc loss=1.0064481496810913, {hms_string(epoch_elapsed)}
# Epoch 134, gen loss=0.6931291222572327,disc loss=1.0064401626586914, {hms_string(epoch_elapsed)}
# Epoch 135, gen loss=0.6931244134902954,disc loss=1.0064468383789062, {hms_string(epoch_elapsed)}
# Epoch 136, gen loss=0.6931213140487671,disc loss=1.006450891494751, {hms_string(epoch_elapsed)}
# Epoch 137, gen loss=0.6931288242340088,disc loss=1.0064421892166138, {hms_string(epoch_elapsed)}
# Epoch 138, gen loss=0.6931291818618774,disc loss=1.006441593170166, {hms_string(epoch_elapsed)}
# Epoch 139, gen loss=0.6931296586990356,disc loss=1.0064418315887451, {hms_string(epoch_elapsed)}
# Epoch 140, gen loss=0.6931302547454834,disc loss=1.0064424276351929, {hms_string(epoch_elapsed)}
# Epoch 141, gen loss=0.6931222677230835,disc loss=1.006446361541748, {hms_string(epoch_elapsed)}
# Epoch 142, gen loss=0.6931272149085999,disc loss=1.0064488649368286, {hms_string(epoch_elapsed)}
# Epoch 143, gen loss=0.6931217908859253,disc loss=1.006447196006775, {hms_string(epoch_elapsed)}
# Epoch 144, gen loss=0.6931263208389282,disc loss=1.0064435005187988, {hms_string(epoch_elapsed)}
# Epoch 145, gen loss=0.6931270956993103,disc loss=1.0064433813095093, {hms_string(epoch_elapsed)}
# Epoch 146, gen loss=0.6931284666061401,disc loss=1.0064373016357422, {hms_string(epoch_elapsed)}
# Epoch 147, gen loss=0.6931228637695312,disc loss=1.006447196006775, {hms_string(epoch_elapsed)}
# Epoch 148, gen loss=0.6931188106536865,disc loss=1.0064494609832764, {hms_string(epoch_elapsed)}
# Epoch 149, gen loss=0.6931344270706177,disc loss=1.0064342021942139, {hms_string(epoch_elapsed)}
# Epoch 150, gen loss=0.693128228187561,disc loss=1.00644052028656, {hms_string(epoch_elapsed)}
# Epoch 151, gen loss=0.6931277513504028,disc loss=1.0064398050308228, {hms_string(epoch_elapsed)}
# Epoch 152, gen loss=0.6931290030479431,disc loss=1.0064400434494019, {hms_string(epoch_elapsed)}
# Epoch 153, gen loss=0.693131685256958,disc loss=1.0064363479614258, {hms_string(epoch_elapsed)}
# Epoch 154, gen loss=0.6931264400482178,disc loss=1.006441354751587, {hms_string(epoch_elapsed)}
# Epoch 155, gen loss=0.6931310296058655,disc loss=1.0064386129379272, {hms_string(epoch_elapsed)}
# Epoch 156, gen loss=0.693130612373352,disc loss=1.0064380168914795, {hms_string(epoch_elapsed)}
# Epoch 157, gen loss=0.6931191682815552,disc loss=1.0064486265182495, {hms_string(epoch_elapsed)}
# Epoch 158, gen loss=0.6931308507919312,disc loss=1.006439208984375, {hms_string(epoch_elapsed)}
# Epoch 159, gen loss=0.6931294202804565,disc loss=1.006438970565796, {hms_string(epoch_elapsed)}
# Epoch 160, gen loss=0.6931282877922058,disc loss=1.006439208984375, {hms_string(epoch_elapsed)}
# Epoch 161, gen loss=0.693135142326355,disc loss=1.0064325332641602, {hms_string(epoch_elapsed)}
# Epoch 162, gen loss=0.6931319236755371,disc loss=1.006436824798584, {hms_string(epoch_elapsed)}
# Epoch 163, gen loss=0.6931290626525879,disc loss=1.0064407587051392, {hms_string(epoch_elapsed)}
# Epoch 164, gen loss=0.6931307315826416,disc loss=1.0064380168914795, {hms_string(epoch_elapsed)}
# Epoch 165, gen loss=0.6931333541870117,disc loss=1.0064356327056885, {hms_string(epoch_elapsed)}
# Epoch 166, gen loss=0.6931360363960266,disc loss=1.0064308643341064, {hms_string(epoch_elapsed)}
# Epoch 167, gen loss=0.6931295990943909,disc loss=1.0064377784729004, {hms_string(epoch_elapsed)}
# Epoch 168, gen loss=0.6931288242340088,disc loss=1.0064373016357422, {hms_string(epoch_elapsed)}
# Epoch 169, gen loss=0.6931312084197998,disc loss=1.0064353942871094, {hms_string(epoch_elapsed)}
# Epoch 170, gen loss=0.693130612373352,disc loss=1.0064363479614258, {hms_string(epoch_elapsed)}
# Epoch 171, gen loss=0.6931276321411133,disc loss=1.0064440965652466, {hms_string(epoch_elapsed)}
# Epoch 172, gen loss=0.6931240558624268,disc loss=1.0064420700073242, {hms_string(epoch_elapsed)}
# Epoch 173, gen loss=0.6931235790252686,disc loss=1.0064427852630615, {hms_string(epoch_elapsed)}
# Epoch 174, gen loss=0.6931354999542236,disc loss=1.0064336061477661, {hms_string(epoch_elapsed)}
# Epoch 175, gen loss=0.6931312680244446,disc loss=1.0064352750778198, {hms_string(epoch_elapsed)}
# Epoch 176, gen loss=0.6931335926055908,disc loss=1.0064349174499512, {hms_string(epoch_elapsed)}
# Epoch 177, gen loss=0.6931338310241699,disc loss=1.0064330101013184, {hms_string(epoch_elapsed)}
# Epoch 178, gen loss=0.6931349039077759,disc loss=1.0064349174499512, {hms_string(epoch_elapsed)}
# Epoch 179, gen loss=0.6931312084197998,disc loss=1.0064337253570557, {hms_string(epoch_elapsed)}
# Epoch 180, gen loss=0.6931301355361938,disc loss=1.0064351558685303, {hms_string(epoch_elapsed)}
# Epoch 181, gen loss=0.6931325197219849,disc loss=1.0064325332641602, {hms_string(epoch_elapsed)}
# Epoch 182, gen loss=0.6931328773498535,disc loss=1.006432294845581, {hms_string(epoch_elapsed)}
# Epoch 183, gen loss=0.6931370496749878,disc loss=1.0064277648925781, {hms_string(epoch_elapsed)}
# Epoch 184, gen loss=0.693135142326355,disc loss=1.0064297914505005, {hms_string(epoch_elapsed)}
# Epoch 185, gen loss=0.6931321620941162,disc loss=1.006432056427002, {hms_string(epoch_elapsed)}
# Epoch 186, gen loss=0.6931320428848267,disc loss=1.0064332485198975, {hms_string(epoch_elapsed)}
# Epoch 187, gen loss=0.6931338906288147,disc loss=1.0064327716827393, {hms_string(epoch_elapsed)}
# Epoch 188, gen loss=0.6931353807449341,disc loss=1.0064277648925781, {hms_string(epoch_elapsed)}
# Epoch 189, gen loss=0.6931362152099609,disc loss=1.006427526473999, {hms_string(epoch_elapsed)}
# Epoch 190, gen loss=0.6931347846984863,disc loss=1.0064302682876587, {hms_string(epoch_elapsed)}
# Epoch 191, gen loss=0.6931352615356445,disc loss=1.0064308643341064, {hms_string(epoch_elapsed)}
# Epoch 192, gen loss=0.6931369304656982,disc loss=1.0064284801483154, {hms_string(epoch_elapsed)}
# Epoch 193, gen loss=0.6931315064430237,disc loss=1.006433129310608, {hms_string(epoch_elapsed)}
# Epoch 194, gen loss=0.6931356191635132,disc loss=1.0064294338226318, {hms_string(epoch_elapsed)}
# Epoch 195, gen loss=0.69313645362854,disc loss=1.0064284801483154, {hms_string(epoch_elapsed)}
# Epoch 196, gen loss=0.6931322813034058,disc loss=1.006432056427002, {hms_string(epoch_elapsed)}
# Epoch 197, gen loss=0.6931337118148804,disc loss=1.0064314603805542, {hms_string(epoch_elapsed)}
# Epoch 198, gen loss=0.6931352019309998,disc loss=1.0064294338226318, {hms_string(epoch_elapsed)}
# Epoch 199, gen loss=0.693135678768158,disc loss=1.0064277648925781, {hms_string(epoch_elapsed)}
# Epoch 200, gen loss=0.6931363344192505,disc loss=1.0064293146133423, {hms_string(epoch_elapsed)}
# Epoch 201, gen loss=0.6931370496749878,disc loss=1.0064282417297363, {hms_string(epoch_elapsed)}
# Epoch 202, gen loss=0.6931320428848267,disc loss=1.0064334869384766, {hms_string(epoch_elapsed)}
# Epoch 203, gen loss=0.6931330561637878,disc loss=1.006430983543396, {hms_string(epoch_elapsed)}
# Epoch 204, gen loss=0.6931345462799072,disc loss=1.0064297914505005, {hms_string(epoch_elapsed)}
# Epoch 205, gen loss=0.6931363344192505,disc loss=1.0064291954040527, {hms_string(epoch_elapsed)}
# Epoch 206, gen loss=0.6931348443031311,disc loss=1.0064289569854736, {hms_string(epoch_elapsed)}
# Epoch 207, gen loss=0.693138599395752,disc loss=1.0064265727996826, {hms_string(epoch_elapsed)}
# Epoch 208, gen loss=0.6931359767913818,disc loss=1.0064305067062378, {hms_string(epoch_elapsed)}
# Epoch 209, gen loss=0.6931372284889221,disc loss=1.0064268112182617, {hms_string(epoch_elapsed)}
# Epoch 210, gen loss=0.6931366920471191,disc loss=1.00642728805542, {hms_string(epoch_elapsed)}
# Epoch 211, gen loss=0.693137526512146,disc loss=1.0064252614974976, {hms_string(epoch_elapsed)}
# Epoch 212, gen loss=0.6931318640708923,disc loss=1.006432056427002, {hms_string(epoch_elapsed)}
# Epoch 213, gen loss=0.6931373476982117,disc loss=1.006425380706787, {hms_string(epoch_elapsed)}
# Epoch 214, gen loss=0.6931323409080505,disc loss=1.0064325332641602, {hms_string(epoch_elapsed)}
# Epoch 215, gen loss=0.6931378245353699,disc loss=1.0064265727996826, {hms_string(epoch_elapsed)}
# Epoch 216, gen loss=0.6931310892105103,disc loss=1.0064315795898438, {hms_string(epoch_elapsed)}
# Epoch 217, gen loss=0.6931369304656982,disc loss=1.0064276456832886, {hms_string(epoch_elapsed)}
# Epoch 218, gen loss=0.6931360363960266,disc loss=1.0064268112182617, {hms_string(epoch_elapsed)}
# Epoch 219, gen loss=0.6931313872337341,disc loss=1.0064347982406616, {hms_string(epoch_elapsed)}
# Epoch 220, gen loss=0.6931376457214355,disc loss=1.0064250230789185, {hms_string(epoch_elapsed)}
# Epoch 221, gen loss=0.6931362748146057,disc loss=1.0064280033111572, {hms_string(epoch_elapsed)}
# Epoch 222, gen loss=0.6931331157684326,disc loss=1.0064289569854736, {hms_string(epoch_elapsed)}
# Epoch 223, gen loss=0.6931354999542236,disc loss=1.0064282417297363, {hms_string(epoch_elapsed)}
# Epoch 224, gen loss=0.6931368708610535,disc loss=1.00642728805542, {hms_string(epoch_elapsed)}
# Epoch 225, gen loss=0.6931353807449341,disc loss=1.0064294338226318, {hms_string(epoch_elapsed)}
# Epoch 226, gen loss=0.6931378245353699,disc loss=1.0064259767532349, {hms_string(epoch_elapsed)}
# Epoch 227, gen loss=0.6931384801864624,disc loss=1.006424903869629, {hms_string(epoch_elapsed)}
# Epoch 228, gen loss=0.693130612373352,disc loss=1.006432056427002, {hms_string(epoch_elapsed)}
# Epoch 229, gen loss=0.6931393146514893,disc loss=1.006422758102417, {hms_string(epoch_elapsed)}
# Epoch 230, gen loss=0.693138837814331,disc loss=1.0064244270324707, {hms_string(epoch_elapsed)}
# Epoch 231, gen loss=0.693138837814331,disc loss=1.0064237117767334, {hms_string(epoch_elapsed)}
# Epoch 232, gen loss=0.6931385397911072,disc loss=1.0064256191253662, {hms_string(epoch_elapsed)}
# Epoch 233, gen loss=0.6931378841400146,disc loss=1.0064254999160767, {hms_string(epoch_elapsed)}
# Epoch 234, gen loss=0.6931344270706177,disc loss=1.0064282417297363, {hms_string(epoch_elapsed)}
# Epoch 235, gen loss=0.6931365132331848,disc loss=1.0064287185668945, {hms_string(epoch_elapsed)}
# Epoch 236, gen loss=0.6931365132331848,disc loss=1.0064263343811035, {hms_string(epoch_elapsed)}
# Epoch 237, gen loss=0.6931380033493042,disc loss=1.0064246654510498, {hms_string(epoch_elapsed)}
# Epoch 238, gen loss=0.6931387186050415,disc loss=1.0064234733581543, {hms_string(epoch_elapsed)}
# Epoch 239, gen loss=0.6931374073028564,disc loss=1.006424903869629, {hms_string(epoch_elapsed)}
# Epoch 240, gen loss=0.6931362152099609,disc loss=1.0064256191253662, {hms_string(epoch_elapsed)}
# Epoch 241, gen loss=0.693137526512146,disc loss=1.0064243078231812, {hms_string(epoch_elapsed)}
# Epoch 242, gen loss=0.693139374256134,disc loss=1.006422519683838, {hms_string(epoch_elapsed)}
# Epoch 243, gen loss=0.6931401491165161,disc loss=1.0064224004745483, {hms_string(epoch_elapsed)}
# Epoch 244, gen loss=0.693139910697937,disc loss=1.0064213275909424, {hms_string(epoch_elapsed)}
# Epoch 245, gen loss=0.6931403875350952,disc loss=1.0064218044281006, {hms_string(epoch_elapsed)}
# Epoch 246, gen loss=0.6931376457214355,disc loss=1.0064250230789185, {hms_string(epoch_elapsed)}
# Epoch 247, gen loss=0.6931374073028564,disc loss=1.0064239501953125, {hms_string(epoch_elapsed)}
# Epoch 248, gen loss=0.6931381821632385,disc loss=1.0064224004745483, {hms_string(epoch_elapsed)}
# Epoch 249, gen loss=0.6931380033493042,disc loss=1.0064241886138916, {hms_string(epoch_elapsed)}
# Epoch 250, gen loss=0.693139910697937,disc loss=1.006421446800232, {hms_string(epoch_elapsed)}
# Epoch 251, gen loss=0.6931395530700684,disc loss=1.0064218044281006, {hms_string(epoch_elapsed)}
# Epoch 252, gen loss=0.6931410431861877,disc loss=1.006420612335205, {hms_string(epoch_elapsed)}
# Epoch 253, gen loss=0.6931378841400146,disc loss=1.006422996520996, {hms_string(epoch_elapsed)}
# Epoch 254, gen loss=0.6931383609771729,disc loss=1.0064239501953125, {hms_string(epoch_elapsed)}
# Epoch 255, gen loss=0.6931406855583191,disc loss=1.006422519683838, {hms_string(epoch_elapsed)}
# Epoch 256, gen loss=0.6931396722793579,disc loss=1.0064213275909424, {hms_string(epoch_elapsed)}
# Epoch 257, gen loss=0.6931396722793579,disc loss=1.0064218044281006, {hms_string(epoch_elapsed)}
# Epoch 258, gen loss=0.6931373476982117,disc loss=1.0064246654510498, {hms_string(epoch_elapsed)}
# Epoch 259, gen loss=0.6931381225585938,disc loss=1.0064231157302856, {hms_string(epoch_elapsed)}
# Epoch 260, gen loss=0.693139910697937,disc loss=1.0064208507537842, {hms_string(epoch_elapsed)}
# Epoch 261, gen loss=0.6931391358375549,disc loss=1.0064234733581543, {hms_string(epoch_elapsed)}
# Epoch 262, gen loss=0.6931400299072266,disc loss=1.0064220428466797, {hms_string(epoch_elapsed)}
# Epoch 263, gen loss=0.6931407451629639,disc loss=1.0064198970794678, {hms_string(epoch_elapsed)}
# Epoch 264, gen loss=0.6931390762329102,disc loss=1.006422519683838, {hms_string(epoch_elapsed)}
# Epoch 265, gen loss=0.6931390762329102,disc loss=1.0064213275909424, {hms_string(epoch_elapsed)}
# Epoch 266, gen loss=0.6931393146514893,disc loss=1.0064209699630737, {hms_string(epoch_elapsed)}
# Epoch 267, gen loss=0.6931390166282654,disc loss=1.0064218044281006, {hms_string(epoch_elapsed)}
# Epoch 268, gen loss=0.6931414008140564,disc loss=1.0064208507537842, {hms_string(epoch_elapsed)}
# Epoch 269, gen loss=0.6931408643722534,disc loss=1.0064208507537842, {hms_string(epoch_elapsed)}
# Epoch 270, gen loss=0.6931394338607788,disc loss=1.0064226388931274, {hms_string(epoch_elapsed)}
# Epoch 271, gen loss=0.6931408643722534,disc loss=1.006421446800232, {hms_string(epoch_elapsed)}
# Epoch 272, gen loss=0.6931393146514893,disc loss=1.0064218044281006, {hms_string(epoch_elapsed)}
# Epoch 273, gen loss=0.6931408643722534,disc loss=1.0064204931259155, {hms_string(epoch_elapsed)}
# Epoch 274, gen loss=0.6931359767913818,disc loss=1.006425142288208, {hms_string(epoch_elapsed)}
# Epoch 275, gen loss=0.6931416392326355,disc loss=1.006420373916626, {hms_string(epoch_elapsed)}
# Epoch 276, gen loss=0.6931390762329102,disc loss=1.0064213275909424, {hms_string(epoch_elapsed)}
# Epoch 277, gen loss=0.6931373476982117,disc loss=1.0064233541488647, {hms_string(epoch_elapsed)}
# Epoch 278, gen loss=0.6931373476982117,disc loss=1.0064246654510498, {hms_string(epoch_elapsed)}
# Epoch 279, gen loss=0.6931363344192505,disc loss=1.0064244270324707, {hms_string(epoch_elapsed)}
# Epoch 280, gen loss=0.6931420564651489,disc loss=1.0064188241958618, {hms_string(epoch_elapsed)}
# Epoch 281, gen loss=0.6931400299072266,disc loss=1.0064213275909424, {hms_string(epoch_elapsed)}
# Epoch 282, gen loss=0.6931400299072266,disc loss=1.0064224004745483, {hms_string(epoch_elapsed)}
# Epoch 283, gen loss=0.693139374256134,disc loss=1.0064219236373901, {hms_string(epoch_elapsed)}
# Epoch 284, gen loss=0.6931402683258057,disc loss=1.0064198970794678, {hms_string(epoch_elapsed)}
# Epoch 285, gen loss=0.6931393146514893,disc loss=1.0064218044281006, {hms_string(epoch_elapsed)}
# Epoch 286, gen loss=0.6931416988372803,disc loss=1.0064184665679932, {hms_string(epoch_elapsed)}
# Epoch 287, gen loss=0.6931396126747131,disc loss=1.006421446800232, {hms_string(epoch_elapsed)}
# Epoch 288, gen loss=0.6931402683258057,disc loss=1.0064204931259155, {hms_string(epoch_elapsed)}
# Epoch 289, gen loss=0.6931400299072266,disc loss=1.006420373916626, {hms_string(epoch_elapsed)}
# Epoch 290, gen loss=0.6931401491165161,disc loss=1.006420612335205, {hms_string(epoch_elapsed)}
# Epoch 291, gen loss=0.6931420564651489,disc loss=1.0064187049865723, {hms_string(epoch_elapsed)}
# Epoch 292, gen loss=0.6931419372558594,disc loss=1.0064184665679932, {hms_string(epoch_elapsed)}
# Epoch 293, gen loss=0.6931416392326355,disc loss=1.0064189434051514, {hms_string(epoch_elapsed)}
# Epoch 294, gen loss=0.6931394338607788,disc loss=1.0064220428466797, {hms_string(epoch_elapsed)}
# Epoch 295, gen loss=0.6931387186050415,disc loss=1.0064226388931274, {hms_string(epoch_elapsed)}
# Epoch 296, gen loss=0.6931412220001221,disc loss=1.0064184665679932, {hms_string(epoch_elapsed)}
# Epoch 297, gen loss=0.6931390762329102,disc loss=1.0064221620559692, {hms_string(epoch_elapsed)}
# Epoch 298, gen loss=0.6931403875350952,disc loss=1.0064188241958618, {hms_string(epoch_elapsed)}
# Epoch 299, gen loss=0.6931408643722534,disc loss=1.0064196586608887, {hms_string(epoch_elapsed)}
# Epoch 300, gen loss=0.6931402087211609,disc loss=1.0064201354980469, {hms_string(epoch_elapsed)}
# Epoch 301, gen loss=0.6931428909301758,disc loss=1.0064170360565186, {hms_string(epoch_elapsed)}
# Epoch 302, gen loss=0.6931408047676086,disc loss=1.0064191818237305, {hms_string(epoch_elapsed)}
# Epoch 303, gen loss=0.6931400299072266,disc loss=1.006420373916626, {hms_string(epoch_elapsed)}
# Epoch 304, gen loss=0.6931408643722534,disc loss=1.0064189434051514, {hms_string(epoch_elapsed)}
# Epoch 305, gen loss=0.6931382417678833,disc loss=1.0064219236373901, {hms_string(epoch_elapsed)}
# Epoch 306, gen loss=0.6931409239768982,disc loss=1.0064189434051514, {hms_string(epoch_elapsed)}
# Epoch 307, gen loss=0.6931407451629639,disc loss=1.00641930103302, {hms_string(epoch_elapsed)}
# Epoch 308, gen loss=0.693142294883728,disc loss=1.0064183473587036, {hms_string(epoch_elapsed)}
# Epoch 309, gen loss=0.693142294883728,disc loss=1.0064181089401245, {hms_string(epoch_elapsed)}
# Epoch 310, gen loss=0.6931411623954773,disc loss=1.0064189434051514, {hms_string(epoch_elapsed)}
# Epoch 311, gen loss=0.6931415796279907,disc loss=1.0064177513122559, {hms_string(epoch_elapsed)}
# Epoch 312, gen loss=0.6931422352790833,disc loss=1.0064183473587036, {hms_string(epoch_elapsed)}
# Epoch 313, gen loss=0.6931420564651489,disc loss=1.0064183473587036, {hms_string(epoch_elapsed)}
# Epoch 314, gen loss=0.6931408047676086,disc loss=1.006419062614441, {hms_string(epoch_elapsed)}
# Epoch 315, gen loss=0.6931401491165161,disc loss=1.0064198970794678, {hms_string(epoch_elapsed)}
# Epoch 316, gen loss=0.693142294883728,disc loss=1.0064184665679932, {hms_string(epoch_elapsed)}
# Epoch 317, gen loss=0.6931414604187012,disc loss=1.006417989730835, {hms_string(epoch_elapsed)}
# Epoch 318, gen loss=0.6931407451629639,disc loss=1.0064196586608887, {hms_string(epoch_elapsed)}
# Epoch 319, gen loss=0.6931397318840027,disc loss=1.006420373916626, {hms_string(epoch_elapsed)}
# Epoch 320, gen loss=0.6931424140930176,disc loss=1.006417155265808, {hms_string(epoch_elapsed)}
# Epoch 321, gen loss=0.6931412816047668,disc loss=1.0064181089401245, {hms_string(epoch_elapsed)}
# Epoch 322, gen loss=0.693142294883728,disc loss=1.0064172744750977, {hms_string(epoch_elapsed)}
# Epoch 323, gen loss=0.6931391954421997,disc loss=1.0064210891723633, {hms_string(epoch_elapsed)}
# Epoch 324, gen loss=0.6931413412094116,disc loss=1.0064196586608887, {hms_string(epoch_elapsed)}
# Epoch 325, gen loss=0.6931402683258057,disc loss=1.0064201354980469, {hms_string(epoch_elapsed)}
# Epoch 326, gen loss=0.6931418180465698,disc loss=1.0064176321029663, {hms_string(epoch_elapsed)}
# Epoch 327, gen loss=0.6931427717208862,disc loss=1.0064177513122559, {hms_string(epoch_elapsed)}
# Epoch 328, gen loss=0.6931377053260803,disc loss=1.006422519683838, {hms_string(epoch_elapsed)}
# Epoch 329, gen loss=0.6931419372558594,disc loss=1.0064175128936768, {hms_string(epoch_elapsed)}
# Epoch 330, gen loss=0.6931372284889221,disc loss=1.0064218044281006, {hms_string(epoch_elapsed)}
# Epoch 331, gen loss=0.6931430101394653,disc loss=1.0064165592193604, {hms_string(epoch_elapsed)}
# Epoch 332, gen loss=0.6931416988372803,disc loss=1.006418228149414, {hms_string(epoch_elapsed)}
# Epoch 333, gen loss=0.693142294883728,disc loss=1.0064175128936768, {hms_string(epoch_elapsed)}
# Epoch 334, gen loss=0.6931419968605042,disc loss=1.0064172744750977, {hms_string(epoch_elapsed)}
# Epoch 335, gen loss=0.6931421160697937,disc loss=1.0064172744750977, {hms_string(epoch_elapsed)}
# Epoch 336, gen loss=0.6931418180465698,disc loss=1.0064189434051514, {hms_string(epoch_elapsed)}
# Epoch 337, gen loss=0.6931418180465698,disc loss=1.0064181089401245, {hms_string(epoch_elapsed)}
# Epoch 338, gen loss=0.6931427717208862,disc loss=1.0064175128936768, {hms_string(epoch_elapsed)}
# Epoch 339, gen loss=0.6931430697441101,disc loss=1.0064163208007812, {hms_string(epoch_elapsed)}
# Epoch 340, gen loss=0.693141758441925,disc loss=1.006418228149414, {hms_string(epoch_elapsed)}
# Epoch 341, gen loss=0.6931432485580444,disc loss=1.0064160823822021, {hms_string(epoch_elapsed)}
# Epoch 342, gen loss=0.6931427717208862,disc loss=1.0064175128936768, {hms_string(epoch_elapsed)}
# Epoch 343, gen loss=0.6931415796279907,disc loss=1.0064187049865723, {hms_string(epoch_elapsed)}
# Epoch 344, gen loss=0.693142294883728,disc loss=1.0064177513122559, {hms_string(epoch_elapsed)}
# Epoch 345, gen loss=0.6931402683258057,disc loss=1.0064191818237305, {hms_string(epoch_elapsed)}
# Epoch 346, gen loss=0.6931422352790833,disc loss=1.0064163208007812, {hms_string(epoch_elapsed)}
# Epoch 347, gen loss=0.6931428909301758,disc loss=1.0064172744750977, {hms_string(epoch_elapsed)}
# Epoch 348, gen loss=0.6931434869766235,disc loss=1.0064154863357544, {hms_string(epoch_elapsed)}
# Epoch 349, gen loss=0.6931420564651489,disc loss=1.006417989730835, {hms_string(epoch_elapsed)}
# Epoch 350, gen loss=0.6931424140930176,disc loss=1.00641667842865, {hms_string(epoch_elapsed)}
# Epoch 351, gen loss=0.6931429505348206,disc loss=1.006417155265808, {hms_string(epoch_elapsed)}
# Epoch 352, gen loss=0.6931412220001221,disc loss=1.0064175128936768, {hms_string(epoch_elapsed)}
# Epoch 353, gen loss=0.693142294883728,disc loss=1.0064183473587036, {hms_string(epoch_elapsed)}
# Epoch 354, gen loss=0.6931419372558594,disc loss=1.0064178705215454, {hms_string(epoch_elapsed)}
# Epoch 355, gen loss=0.6931430101394653,disc loss=1.0064159631729126, {hms_string(epoch_elapsed)}
# Epoch 356, gen loss=0.6931420564651489,disc loss=1.0064170360565186, {hms_string(epoch_elapsed)}
# Epoch 357, gen loss=0.6931431293487549,disc loss=1.0064165592193604, {hms_string(epoch_elapsed)}
# Epoch 358, gen loss=0.6931427121162415,disc loss=1.0064164400100708, {hms_string(epoch_elapsed)}
# Epoch 359, gen loss=0.6931418180465698,disc loss=1.006417155265808, {hms_string(epoch_elapsed)}
# Epoch 360, gen loss=0.6931436061859131,disc loss=1.006415605545044, {hms_string(epoch_elapsed)}
# Epoch 361, gen loss=0.6931434869766235,disc loss=1.006415843963623, {hms_string(epoch_elapsed)}
# Epoch 362, gen loss=0.6931416988372803,disc loss=1.0064184665679932, {hms_string(epoch_elapsed)}
# Epoch 363, gen loss=0.6931446194648743,disc loss=1.0064144134521484, {hms_string(epoch_elapsed)}
# Epoch 364, gen loss=0.6931401491165161,disc loss=1.0064187049865723, {hms_string(epoch_elapsed)}
# Epoch 365, gen loss=0.6931424140930176,disc loss=1.0064176321029663, {hms_string(epoch_elapsed)}
# Epoch 366, gen loss=0.6931419372558594,disc loss=1.0064165592193604, {hms_string(epoch_elapsed)}
# Epoch 367, gen loss=0.693143904209137,disc loss=1.0064165592193604, {hms_string(epoch_elapsed)}
# Epoch 368, gen loss=0.6931421160697937,disc loss=1.0064165592193604, {hms_string(epoch_elapsed)}
# Epoch 369, gen loss=0.6931425929069519,disc loss=1.0064173936843872, {hms_string(epoch_elapsed)}
# Epoch 370, gen loss=0.6931427717208862,disc loss=1.006415605545044, {hms_string(epoch_elapsed)}
# Epoch 371, gen loss=0.6931423544883728,disc loss=1.0064159631729126, {hms_string(epoch_elapsed)}
# Epoch 372, gen loss=0.6931424736976624,disc loss=1.006415843963623, {hms_string(epoch_elapsed)}
# Epoch 373, gen loss=0.6931414008140564,disc loss=1.0064176321029663, {hms_string(epoch_elapsed)}
# Epoch 374, gen loss=0.6931425929069519,disc loss=1.0064157247543335, {hms_string(epoch_elapsed)}
# Epoch 375, gen loss=0.693143367767334,disc loss=1.0064151287078857, {hms_string(epoch_elapsed)}
# Epoch 376, gen loss=0.6931431293487549,disc loss=1.0064160823822021, {hms_string(epoch_elapsed)}
# Epoch 377, gen loss=0.6931434869766235,disc loss=1.006415605545044, {hms_string(epoch_elapsed)}
# Epoch 378, gen loss=0.6931436061859131,disc loss=1.0064151287078857, {hms_string(epoch_elapsed)}
# Epoch 379, gen loss=0.6931428909301758,disc loss=1.0064159631729126, {hms_string(epoch_elapsed)}
# Epoch 380, gen loss=0.6931424736976624,disc loss=1.0064164400100708, {hms_string(epoch_elapsed)}
# Epoch 381, gen loss=0.6931418776512146,disc loss=1.006417155265808, {hms_string(epoch_elapsed)}
# Epoch 382, gen loss=0.6931416988372803,disc loss=1.0064167976379395, {hms_string(epoch_elapsed)}
# Epoch 383, gen loss=0.6931426525115967,disc loss=1.0064160823822021, {hms_string(epoch_elapsed)}
# Epoch 384, gen loss=0.6931419372558594,disc loss=1.0064167976379395, {hms_string(epoch_elapsed)}
# Epoch 385, gen loss=0.6931405663490295,disc loss=1.006419062614441, {hms_string(epoch_elapsed)}
# Epoch 386, gen loss=0.6931428909301758,disc loss=1.006415605545044, {hms_string(epoch_elapsed)}
# Epoch 387, gen loss=0.6931429505348206,disc loss=1.006415605545044, {hms_string(epoch_elapsed)}
# Epoch 388, gen loss=0.6931430101394653,disc loss=1.0064159631729126, {hms_string(epoch_elapsed)}
# Epoch 389, gen loss=0.6931445598602295,disc loss=1.006414771080017, {hms_string(epoch_elapsed)}
# Epoch 390, gen loss=0.6931443810462952,disc loss=1.0064141750335693, {hms_string(epoch_elapsed)}
# Epoch 391, gen loss=0.6931436657905579,disc loss=1.0064148902893066, {hms_string(epoch_elapsed)}
# Epoch 392, gen loss=0.6931437253952026,disc loss=1.0064153671264648, {hms_string(epoch_elapsed)}
# Epoch 393, gen loss=0.6931437253952026,disc loss=1.0064146518707275, {hms_string(epoch_elapsed)}
# Epoch 394, gen loss=0.693144679069519,disc loss=1.006414532661438, {hms_string(epoch_elapsed)}
# Epoch 395, gen loss=0.6931442022323608,disc loss=1.0064148902893066, {hms_string(epoch_elapsed)}
# Epoch 396, gen loss=0.6931421756744385,disc loss=1.0064159631729126, {hms_string(epoch_elapsed)}
# Epoch 397, gen loss=0.6931431889533997,disc loss=1.0064153671264648, {hms_string(epoch_elapsed)}
# Epoch 398, gen loss=0.6931429505348206,disc loss=1.0064153671264648, {hms_string(epoch_elapsed)}
# Epoch 399, gen loss=0.6931437253952026,disc loss=1.0064151287078857, {hms_string(epoch_elapsed)}
# Epoch 400, gen loss=0.6931440830230713,disc loss=1.0064139366149902, {hms_string(epoch_elapsed)}
# Epoch 401, gen loss=0.6931431889533997,disc loss=1.006415605545044, {hms_string(epoch_elapsed)}
# Epoch 402, gen loss=0.6931442022323608,disc loss=1.0064144134521484, {hms_string(epoch_elapsed)}
# Epoch 403, gen loss=0.6931415796279907,disc loss=1.0064175128936768, {hms_string(epoch_elapsed)}
# Epoch 404, gen loss=0.6931449174880981,disc loss=1.0064135789871216, {hms_string(epoch_elapsed)}
# Epoch 405, gen loss=0.693142831325531,disc loss=1.006415843963623, {hms_string(epoch_elapsed)}
# Epoch 406, gen loss=0.6931441426277161,disc loss=1.0064144134521484, {hms_string(epoch_elapsed)}
# Epoch 407, gen loss=0.6931440830230713,disc loss=1.0064141750335693, {hms_string(epoch_elapsed)}
# Epoch 408, gen loss=0.6931423544883728,disc loss=1.006415843963623, {hms_string(epoch_elapsed)}
# Epoch 409, gen loss=0.6931432485580444,disc loss=1.0064152479171753, {hms_string(epoch_elapsed)}
# Epoch 410, gen loss=0.6931443214416504,disc loss=1.0064144134521484, {hms_string(epoch_elapsed)}
# Epoch 411, gen loss=0.693143904209137,disc loss=1.0064146518707275, {hms_string(epoch_elapsed)}
# Epoch 412, gen loss=0.6931433081626892,disc loss=1.0064150094985962, {hms_string(epoch_elapsed)}
# Epoch 413, gen loss=0.6931442022323608,disc loss=1.0064148902893066, {hms_string(epoch_elapsed)}
# Epoch 414, gen loss=0.6931408643722534,disc loss=1.0064177513122559, {hms_string(epoch_elapsed)}
# Epoch 415, gen loss=0.6931440830230713,disc loss=1.0064142942428589, {hms_string(epoch_elapsed)}
# Epoch 416, gen loss=0.6931431889533997,disc loss=1.0064154863357544, {hms_string(epoch_elapsed)}
# Epoch 417, gen loss=0.6931430101394653,disc loss=1.0064151287078857, {hms_string(epoch_elapsed)}
# Epoch 418, gen loss=0.693144679069519,disc loss=1.0064138174057007, {hms_string(epoch_elapsed)}
# Epoch 419, gen loss=0.6931443214416504,disc loss=1.006414771080017, {hms_string(epoch_elapsed)}
# Epoch 420, gen loss=0.6931434869766235,disc loss=1.0064146518707275, {hms_string(epoch_elapsed)}
# Epoch 421, gen loss=0.693144679069519,disc loss=1.0064136981964111, {hms_string(epoch_elapsed)}
# Epoch 422, gen loss=0.6931432485580444,disc loss=1.0064159631729126, {hms_string(epoch_elapsed)}
# Epoch 423, gen loss=0.6931437253952026,disc loss=1.0064146518707275, {hms_string(epoch_elapsed)}
# Epoch 424, gen loss=0.6931436061859131,disc loss=1.006414771080017, {hms_string(epoch_elapsed)}
# Epoch 425, gen loss=0.6931437253952026,disc loss=1.0064146518707275, {hms_string(epoch_elapsed)}
# Epoch 426, gen loss=0.6931424736976624,disc loss=1.0064157247543335, {hms_string(epoch_elapsed)}
# Epoch 427, gen loss=0.6931437253952026,disc loss=1.006414532661438, {hms_string(epoch_elapsed)}
# Epoch 428, gen loss=0.6931446194648743,disc loss=1.0064139366149902, {hms_string(epoch_elapsed)}
# Epoch 429, gen loss=0.6931444406509399,disc loss=1.0064136981964111, {hms_string(epoch_elapsed)}
# Epoch 430, gen loss=0.6931445598602295,disc loss=1.0064148902893066, {hms_string(epoch_elapsed)}
# Epoch 431, gen loss=0.6931436061859131,disc loss=1.0064146518707275, {hms_string(epoch_elapsed)}
# Epoch 432, gen loss=0.6931432485580444,disc loss=1.0064163208007812, {hms_string(epoch_elapsed)}
# Epoch 433, gen loss=0.6931447982788086,disc loss=1.006413459777832, {hms_string(epoch_elapsed)}
# Epoch 434, gen loss=0.6931438446044922,disc loss=1.0064141750335693, {hms_string(epoch_elapsed)}
# Epoch 435, gen loss=0.6931438446044922,disc loss=1.0064139366149902, {hms_string(epoch_elapsed)}
# Epoch 436, gen loss=0.6931428909301758,disc loss=1.0064153671264648, {hms_string(epoch_elapsed)}
# Epoch 437, gen loss=0.6931414604187012,disc loss=1.0064164400100708, {hms_string(epoch_elapsed)}
# Epoch 438, gen loss=0.6931444406509399,disc loss=1.0064136981964111, {hms_string(epoch_elapsed)}
# Epoch 439, gen loss=0.6931444406509399,disc loss=1.006413459777832, {hms_string(epoch_elapsed)}
# Epoch 440, gen loss=0.6931431293487549,disc loss=1.0064153671264648, {hms_string(epoch_elapsed)}
# Epoch 441, gen loss=0.6931443214416504,disc loss=1.0064139366149902, {hms_string(epoch_elapsed)}
# Epoch 442, gen loss=0.6931444406509399,disc loss=1.0064136981964111, {hms_string(epoch_elapsed)}
# Epoch 443, gen loss=0.693143904209137,disc loss=1.0064144134521484, {hms_string(epoch_elapsed)}
# Epoch 444, gen loss=0.6931414604187012,disc loss=1.0064163208007812, {hms_string(epoch_elapsed)}
# Epoch 445, gen loss=0.6931445598602295,disc loss=1.0064135789871216, {hms_string(epoch_elapsed)}
# Epoch 446, gen loss=0.6931440830230713,disc loss=1.0064136981964111, {hms_string(epoch_elapsed)}
# Epoch 447, gen loss=0.6931442618370056,disc loss=1.0064144134521484, {hms_string(epoch_elapsed)}
# Epoch 448, gen loss=0.6931442618370056,disc loss=1.0064135789871216, {hms_string(epoch_elapsed)}
# Epoch 449, gen loss=0.6931437253952026,disc loss=1.0064146518707275, {hms_string(epoch_elapsed)}
# Epoch 450, gen loss=0.6931435465812683,disc loss=1.0064151287078857, {hms_string(epoch_elapsed)}
# Epoch 451, gen loss=0.6931450366973877,disc loss=1.0064131021499634, {hms_string(epoch_elapsed)}
# Epoch 452, gen loss=0.6931431293487549,disc loss=1.0064151287078857, {hms_string(epoch_elapsed)}
# Epoch 453, gen loss=0.6931447386741638,disc loss=1.0064133405685425, {hms_string(epoch_elapsed)}
# Epoch 454, gen loss=0.6931448578834534,disc loss=1.0064129829406738, {hms_string(epoch_elapsed)}
# Epoch 455, gen loss=0.6931450366973877,disc loss=1.006413221359253, {hms_string(epoch_elapsed)}
# Epoch 456, gen loss=0.6931442022323608,disc loss=1.0064146518707275, {hms_string(epoch_elapsed)}
# Epoch 457, gen loss=0.6931436061859131,disc loss=1.0064142942428589, {hms_string(epoch_elapsed)}
# Epoch 458, gen loss=0.6931431293487549,disc loss=1.0064153671264648, {hms_string(epoch_elapsed)}
# Epoch 459, gen loss=0.6931436657905579,disc loss=1.006414771080017, {hms_string(epoch_elapsed)}
# Epoch 460, gen loss=0.6931440830230713,disc loss=1.0064136981964111, {hms_string(epoch_elapsed)}
# Epoch 461, gen loss=0.6931437253952026,disc loss=1.0064141750335693, {hms_string(epoch_elapsed)}
# Epoch 462, gen loss=0.6931440830230713,disc loss=1.0064140558242798, {hms_string(epoch_elapsed)}
# Epoch 463, gen loss=0.6931437253952026,disc loss=1.0064139366149902, {hms_string(epoch_elapsed)}
# Epoch 464, gen loss=0.6931442618370056,disc loss=1.006413459777832, {hms_string(epoch_elapsed)}
# Epoch 465, gen loss=0.693143904209137,disc loss=1.0064141750335693, {hms_string(epoch_elapsed)}
# Epoch 466, gen loss=0.693144679069519,disc loss=1.0064138174057007, {hms_string(epoch_elapsed)}
# Epoch 467, gen loss=0.6931448578834534,disc loss=1.0064129829406738, {hms_string(epoch_elapsed)}
# Epoch 468, gen loss=0.6931447982788086,disc loss=1.0064129829406738, {hms_string(epoch_elapsed)}
# Epoch 469, gen loss=0.6931430697441101,disc loss=1.0064148902893066, {hms_string(epoch_elapsed)}
# Epoch 470, gen loss=0.6931436061859131,disc loss=1.0064144134521484, {hms_string(epoch_elapsed)}
# Epoch 471, gen loss=0.6931451559066772,disc loss=1.0064127445220947, {hms_string(epoch_elapsed)}
# Epoch 472, gen loss=0.6931445598602295,disc loss=1.006413459777832, {hms_string(epoch_elapsed)}
# Epoch 473, gen loss=0.6931445598602295,disc loss=1.0064133405685425, {hms_string(epoch_elapsed)}
# Epoch 474, gen loss=0.6931449174880981,disc loss=1.0064129829406738, {hms_string(epoch_elapsed)}
# Epoch 475, gen loss=0.6931453943252563,disc loss=1.0064127445220947, {hms_string(epoch_elapsed)}
# Epoch 476, gen loss=0.6931450366973877,disc loss=1.0064127445220947, {hms_string(epoch_elapsed)}
# Epoch 477, gen loss=0.6931451559066772,disc loss=1.0064125061035156, {hms_string(epoch_elapsed)}
# Epoch 478, gen loss=0.693144679069519,disc loss=1.006413459777832, {hms_string(epoch_elapsed)}
# Epoch 479, gen loss=0.6931453347206116,disc loss=1.0064128637313843, {hms_string(epoch_elapsed)}
# Epoch 480, gen loss=0.6931437253952026,disc loss=1.0064136981964111, {hms_string(epoch_elapsed)}
# Epoch 481, gen loss=0.6931451559066772,disc loss=1.0064128637313843, {hms_string(epoch_elapsed)}
# Epoch 482, gen loss=0.6931449174880981,disc loss=1.0064128637313843, {hms_string(epoch_elapsed)}
# Epoch 483, gen loss=0.6931443214416504,disc loss=1.0064139366149902, {hms_string(epoch_elapsed)}
# Epoch 484, gen loss=0.6931440830230713,disc loss=1.0064135789871216, {hms_string(epoch_elapsed)}
# Epoch 485, gen loss=0.693144679069519,disc loss=1.006413221359253, {hms_string(epoch_elapsed)}
# Epoch 486, gen loss=0.6931438446044922,disc loss=1.0064139366149902, {hms_string(epoch_elapsed)}
# Epoch 487, gen loss=0.6931440830230713,disc loss=1.0064138174057007, {hms_string(epoch_elapsed)}
# Epoch 488, gen loss=0.6931444406509399,disc loss=1.0064144134521484, {hms_string(epoch_elapsed)}
# Epoch 489, gen loss=0.6931443810462952,disc loss=1.006413459777832, {hms_string(epoch_elapsed)}
# Epoch 490, gen loss=0.6931443214416504,disc loss=1.0064138174057007, {hms_string(epoch_elapsed)}
# Epoch 491, gen loss=0.6931453943252563,disc loss=1.006412386894226, {hms_string(epoch_elapsed)}
# Epoch 492, gen loss=0.6931451559066772,disc loss=1.006412386894226, {hms_string(epoch_elapsed)}
# Epoch 493, gen loss=0.6931445598602295,disc loss=1.006413459777832, {hms_string(epoch_elapsed)}
# Epoch 494, gen loss=0.6931447386741638,disc loss=1.0064129829406738, {hms_string(epoch_elapsed)}
# Epoch 495, gen loss=0.693144679069519,disc loss=1.0064127445220947, {hms_string(epoch_elapsed)}
# Epoch 496, gen loss=0.6931449770927429,disc loss=1.006413221359253, {hms_string(epoch_elapsed)}
# Epoch 497, gen loss=0.6931424140930176,disc loss=1.0064157247543335, {hms_string(epoch_elapsed)}
# ...
# Epoch 2726, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2727, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2728, gen loss=0.6931471228599548,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2729, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2730, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2731, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2732, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2733, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2734, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2735, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2736, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2737, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2738, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2739, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2740, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2741, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2742, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2743, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2744, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2745, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2746, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2747, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2748, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2749, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2750, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2751, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2752, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2753, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2754, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2755, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2756, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2757, gen loss=0.6931470632553101,disc loss=1.0064091682434082, {hms_string(epoch_elapsed)}
# Epoch 2758, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2759, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2760, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2761, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2762, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2763, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2764, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2765, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2766, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2767, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2768, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2769, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2770, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2771, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2772, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2773, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2774, gen loss=0.6931471228599548,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2775, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2776, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2777, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2778, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2779, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2780, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2781, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2782, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2783, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2784, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2785, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2786, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2787, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2788, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2789, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2790, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2791, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2792, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2793, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2794, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2795, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2796, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2797, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2798, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2799, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2800, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2801, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2802, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2803, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2804, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2805, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2806, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2807, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2808, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2809, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2810, gen loss=0.6931470632553101,disc loss=1.0064091682434082, {hms_string(epoch_elapsed)}
# Epoch 2811, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2812, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2813, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2814, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2815, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2816, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2817, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2818, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2819, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2820, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2821, gen loss=0.6931471228599548,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2822, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2823, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2824, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2825, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2826, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2827, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2828, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2829, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2830, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2831, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2832, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2833, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2834, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2835, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2836, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2837, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2838, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2839, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2840, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2841, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2842, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2843, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2844, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2845, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2846, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2847, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2848, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2849, gen loss=0.6931471228599548,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2850, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2851, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2852, gen loss=0.6931471228599548,disc loss=1.0064090490341187, {hms_string(epoch_elapsed)}
# Epoch 2853, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2854, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2855, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2856, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2857, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2858, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2859, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2860, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# Epoch 2861, gen loss=0.6931471824645996,disc loss=1.006408929824829, {hms_string(epoch_elapsed)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-d152560ca122> in <module>()
# ----> 1 train(train_dataset, EPOCHS)
#
# <ipython-input-44-925a4567bc3f> in train(dataset, epochs)
#      10     disc_loss_list = []
#      11
# ---> 12     for image_batch in dataset:
#      13       t = train_step(image_batch)
#      14       gen_loss_list.append(t[0])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     413     """
#     414     if context.executing_eagerly() or ops.inside_function():
# --> 415       return iterator_ops.OwnedIterator(self)
#     416     else:
#     417       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec, job_token)
#     694           context.context().device_spec.device_type != "CPU"):
#     695         with ops.device("/cpu:0"):
# --> 696           self._create_iterator(dataset)
#     697       else:
#     698         self._create_iterator(dataset)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     700   def _create_iterator(self, dataset):
#     701     # pylint: disable=protected-access
# --> 702     dataset = dataset._apply_options()
#     703
#     704     # Store dataset reference to ensure that dataset is alive when this iterator
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py in _apply_options(self)
#     385       else:
#     386         dataset = _OptimizeDataset(dataset, graph_rewrites,
# --> 387                                    graph_rewrite_configs)
#     388
#     389     # (3) Apply autotune options
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, optimizations, optimization_configs)
#    4398         self._optimizations,
#    4399         optimization_configs=optimization_configs,
# -> 4400         **self._flat_structure)
#    4401     super(_OptimizeDataset, self).__init__(input_dataset, variant_tensor)
#    4402
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in optimize_dataset(input_dataset, optimizations, output_types, output_shapes, optimization_configs, name)
#    3946         tld.op_callbacks, input_dataset, optimizations, "output_types",
#    3947         output_types, "output_shapes", output_shapes, "optimization_configs",
# -> 3948         optimization_configs)
#    3949       return _result
#    3950     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
generator.save(os.path.join(DATA_PATH,"face_generator.h5"))
